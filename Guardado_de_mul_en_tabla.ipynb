# %% [markdown]
# <a href="https://colab.research.google.com/github/Shirokoeki/a/blob/main/Guardado_de_mul_en_tabla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tabla = []
num = 0
cont = 0
num = int(input("Numero: "))
for l in range(1,11):
  mul = num * l
  tabla.insert(cont, mul)
  cont += 1

print(tabla)
# Out:
# Numero: 3
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30]
