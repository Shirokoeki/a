# %% [markdown]
# <a href="https://colab.research.google.com/github/Shirokoeki/a/blob/main/Usuario_definitivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
u1 = None
u2 = None
u3 = None
c1 = None
c2 = None
c3 = None
sel = 0
new1 = False
new2 = False
new3 = False

while sel < 3:
   
    print("======================")
    print("1. Iniciar Sesion")
    print("2. Registrarse")
    print("3. Salir")
    try: 
      sel = int(input("Que desea hacer: "))
    except:
      print("Se produjo un error")
    print("======================")
    if sel == 1 and u1 == None and u2 == None and u3 == None:
      print("No existen usuarios registrados")
    if sel == 3:
      print("Gracias por usar el sistema")

    if sel == 1 and new1 == True:
      try:
        print("Ingrese nombre de usuario: ")
        ing = input()
        print("Ingrese contraseña: ")
        ingc = input()
        if ing == u1 and ingc == c1 or ing == u2 and ingc == c2 or ing == u3 and ingc == c3:
          sel2 = 0
          print("Ingreso exitoso")
          while sel2 < 3:      
            print("======================")
            print("1. Realizar llamada")
            print("2. Enviar correo electronico")
            print("3. Cerrar Sesion")
            sel2 = int(input())
            print("======================")

            if sel2 == 3:

              print("Cerrando sesion")
            elif sel2 == 2:
              s = 0
              while s < 1:
                print("Ingrese correo electronico")
                correo = str(input())
                a = any(c == '@' for c in correo)
                if a == True:
                  print("Mensaje a enviar: ")
                  mensaje = input()
                  print("Presione 1 para volver al inicio")
                  s = int(input())

            elif sel2 == 1:
              u = 0
              while u < 1:
                print("Ingrese numero celular: ")
                print("(No olvides empezar con 9 y sin signos)")
                telefono = str(input())
                b = any(r == "9" for r in telefono)
                if b == True and len(telefono) == 8:
                   print("Llamada realizada")
                   u = 2
                elif len(telefono) == 9:
                   print("muy largo")
                else:
                   print("Recuerda que debes empezar con 9 y el numero debe ser de 8 digitos")
            else:
              print("Error, vuelva a intentarlo")
              sel2 = 0
        else:
          print("error de usuario")
      except:
        print("Parece que hubo un error") 
     

    if sel == 2 :
      if u1 == None:
        try:
          print("Crear Usuario")
          print("========================")
          print("Nombre de Usuario: ")
          u1 = input()
          print("Contraseña")
          c1 = input()
          new1 = True
        except:
          print("Error en la creacion")
      elif u1 != None and u2 == None:
        try:
          print("Crear Usuario")
          print("========================")
          print("Nombre de Usuario: ")
          u2 = input()
          print("Contraseña")
          c2 = input()
          new2 = True
        except:
          print("Error en la creacion")
      elif u1 != None and u2 != None and u3 == None:
        try:
          print("Crear Usuario")
          print("========================")
          print("Nombre de Usuario: ")
          u3 = input()
          print("Contraseña")
          c3 = input()
          new2 = True
        except:
          print("Error en la creacion")
      else:
        print("No mas usuarios")
# Out:
# ...
# 1. Iniciar Sesion
# 2. Registrarse
# 3. Salir
# Que desea hacer: 2
# ...
# Crear Usuario
# ...
# Nombre de Usuario:
# a
# Contraseña
# 1
# ...
# 1. Iniciar Sesion
# 2. Registrarse
# 3. Salir
# Que desea hacer: 1
# ...
# Ingrese nombre de usuario:
# a
# Ingrese contraseña:
# 1
# Ingreso exitoso
# ...
# 1. Realizar llamada
# 2. Enviar correo electronico
# 3. Cerrar Sesion
# 1
# ...
# Ingrese numero celular:
# (No olvides empezar con 9 y sin signos)
# 921378137213213
# Recuerda que debes empezar con 9 y el numero debe ser de 8 digitos
# Ingrese numero celular:
# (No olvides empezar con 9 y sin signos)
# 91234567
# Llamada realizada
# ...
# 1. Realizar llamada
# 2. Enviar correo electronico
# 3. Cerrar Sesion
# 3
# ...
# Cerrando sesion
# ...
# 1. Iniciar Sesion
# 2. Registrarse
# 3. Salir
# Que desea hacer: 3
# ...
# Gracias por usar el sistema
