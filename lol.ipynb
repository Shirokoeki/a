# %% [markdown]
# <a href="https://colab.research.google.com/github/Shirokoeki/a/blob/main/lol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ZS = 66
ZSUHI = 66
ZK = 33
ZT = 33
op = 1
a1 = 0
a2 = 0
a3 = 0
a4 = 0
C1 = 0
C2 = 0
C3 = 0
C4 = 0
p1 = 500000
p2 = 350000
p3 = 150000
p4 = 50000

while op > 0:
  print('\033[1m'+"MENU VENTA DE ASIENTO PREMIUM"+'\033[1m')
  print("1. Zona SATOSHI", "(Disponibilidad :",ZS,")")
  print("2. Zona SUHISWAP", "(Disponibilidad :",ZSUHI,")")
  print("3. Zona KUZAMA", "(Disponibilidad :",ZK,")")
  print("4. Zona TRON", "(Disponibilidad :",ZT,")")
  print("0. Salir")
  try:
    op = int(input("Opcion?               :"))
    if op > 0:
      asientos = int(input("Cantidad de asientos? :"))
  except:
    print("                                   ")
    print("*** Alerta: Compra NO ejecutada ***")
  if op == 1 and asientos <= ZS:
    C1 =+ 1
    a1 += asientos
    ZS = ZS - asientos
    print("                 ")
    print("*** Compra OK ***")
    print("                 ")
  elif op == 2 and asientos <= ZSUHI:
    C2 =+ 1
    a2 =+ asientos
    ZSUHI = ZSUHI - asientos
    print("                 ")
    print("*** Compra OK ***")
    print("                 ")
  elif op == 3 and asientos <= ZK:
    C3 =+ 1
    a3 =+ asientos
    ZK = ZK - asientos
    print("                 ")
    print("*** Compra OK ***")
    print("                 ")
  elif op == 4 and asientos <= ZT:
    C4 =+ 1
    a4 =+ asientos
    ZT = ZT - asientos
    print("                 ")
    print("*** Compra OK ***")
    print("                 ")
  elif op == 0 and a1 == 0 and a2 == 0 and a3 == 0 and a4 == 0:
    print("                         ")
    print("*** FIN DE LA VENTA ***  ")
    print("*** REVISE EL RESUMEN ***")
    print("                         ")
    print("**** RESUMEN VENTAS DE ENTRADAS ****                                                    ")
    print("                                                                                        ")
    print("              Cantidad          Asientos         Asientos             SubTotal          ")
    print(" ZONA        Compradores        Vendidos        Disponibles            Venta            ")
    print("                                                                                        ")
    print("SATOSHI          ",C1,"              ",a1,"             ",ZS,"                 $ 0      ")
    print("SUSHISWAP        ",C2,"              ",a2,"             ",ZSUHI,"                 $ 0   ")
    print("KUSAMA           ",C3,"              ",a3,"             ",ZK,"                 $ 0      ")
    print("TRON             ",C4,"              ",a4,"             ",ZT,"                 $ 0      ")
    print("                                                                                        ")
    print("TOTAL            ",tc,"              ",ta,"             ",tz,"                $ 0       ")
  elif op == 0:
    t1 = a1 + p1
    t2 = a2 + p2
    t3 = a3 + p3
    t4 = a4 + p4
    tc = C1 + C2 + C3 + C4
    ta = a1 + a2 + a3 + a4
    tz = ZS + ZSUHI + ZK + ZT
    tf = t1 + t2 + t3 + t4
    print("                         ")
    print("*** FIN DE LA VENTA ***  ")
    print("*** REVISE EL RESUMEN ***")
    print("                         ")
    print("**** RESUMEN VENTAS DE ENTRADAS ****                                                    ")
    print("                                                                                        ")
    print("              Cantidad          Asientos         Asientos             SubTotal          ")
    print(" ZONA        Compradores        Vendidos        Disponibles            Venta            ")
    print("                                                                                        ")
    print("SATOSHI          ",C1,"              ",a1,"             ",ZS,"            $  ",t1,"     ")
    print("SUSHISWAP        ",C2,"              ",a2,"            ",ZSUHI,"             $  ",t2,"  ")
    print("KUSAMA           ",C3,"              ",a3,"             ",ZK,"            $  ",t3,"     ")
    print("TRON             ",C4,"              ",a4,"             ",ZT,"            $  ",t4,"     ")
    print("                                                                                        ")
    print("TOTAL            ",tc,"              ",ta,"             ",tz,"            $ ",tf,"       ")
  else:
    print("                                   ")
    print("*** Alerta: Compra NO ejecutada ***")
# Out:
# MENU VENTA DE ASIENTO PREMIUM
# 1. Zona SATOSHI (Disponibilidad : 66 )
# 2. Zona SUHISWAP (Disponibilidad : 66 )
# 3. Zona KUZAMA (Disponibilidad : 33 )
# 4. Zona TRON (Disponibilidad : 33 )
# 0. Salir
# Opcion?               :1
# Cantidad de asientos? :45
#
# *** Compra OK ***
#
# MENU VENTA DE ASIENTO PREMIUM
# 1. Zona SATOSHI (Disponibilidad : 21 )
# 2. Zona SUHISWAP (Disponibilidad : 66 )
# 3. Zona KUZAMA (Disponibilidad : 33 )
# 4. Zona TRON (Disponibilidad : 33 )
# 0. Salir
# Opcion?               :1
# Cantidad de asientos? :21
#
# *** Compra OK ***
#
# MENU VENTA DE ASIENTO PREMIUM
# 1. Zona SATOSHI (Disponibilidad : 0 )
# 2. Zona SUHISWAP (Disponibilidad : 66 )
# 3. Zona KUZAMA (Disponibilidad : 33 )
# 4. Zona TRON (Disponibilidad : 33 )
# 0. Salir
# Opcion?               :2
# Cantidad de asientos? :33
#
# *** Compra OK ***
#
# MENU VENTA DE ASIENTO PREMIUM
# 1. Zona SATOSHI (Disponibilidad : 0 )
# 2. Zona SUHISWAP (Disponibilidad : 33 )
# ...
